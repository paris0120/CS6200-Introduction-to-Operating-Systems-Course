// %% [markdown]
// ## Learning Goals
// 1. What are OS
// 1. Why are OS needed
// 1. How are OS designed and implemented

// %% [markdown]
// ## Course Topics
// OS abstractions, mechanisms, and policies for
// 1. processes and process management
// 1. threads and concurrentcy
// 1. resource managment: scheduling, memory management
// 1. OS services for communication and I/O
// 1. OS support for distributed services
// 1. Systems software for datacenter and cloud environments

// %% [markdown]
// ## Projects
// 1. Threads, concurrency and synchronization
// 1. single-node OS mechanisms
//     1. inter-process
//     1. communication
//     1. scheduling
// 1. multi-node OS mechanisms
//     1. remote procedure calls (RPC)
// 1. experimented design and evaluation

// %% [markdown]
// ## Books
// ![image.png](attachment:image.png)
// ![image-2.png](attachment:image-2.png)
